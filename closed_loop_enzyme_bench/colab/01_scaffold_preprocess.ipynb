# %% [markdown]
# # 01 — Scaffold fetch & preprocess

# %%
# !pip -q install transformers accelerate biopython pandas numpy matplotlib tqdm scikit-learn pyyaml
import torch, platform
print("torch", torch.__version__, "cuda?", torch.cuda.is_available(), "python", platform.python_version())
# Out:
# 'pip'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# torch 2.9.1+cpu cuda? False python 3.14.2

# %%
import sys
import os
import json
import time
from pathlib import Path

# Add parent directory to sys.path to find 'src' module
current_dir = Path(os.getcwd())
if current_dir.name == "colab":
    # If running from colab dir, add parent
    parent_dir = str(current_dir.parent)
    if parent_dir not in sys.path:
        sys.path.append(parent_dir)

# #region agent log
log_path = r"c:\Users\Mr.Josh\Documents\GitHub\bioinformatics\.cursor\debug.log"
def log_debug(msg, data):
    try:
        entry = {
            "id": f"log_{time.time()}",
            "timestamp": int(time.time() * 1000),
            "location": "01_scaffold_preprocess.ipynb:Cell2",
            "message": msg,
            "data": data,
            "sessionId": "debug-session",
            "runId": "run2_fix_attempt",
            "hypothesisId": "sys_path_fix_verification"
        }
        with open(log_path, "a", encoding="utf-8") as f:
            f.write(json.dumps(entry) + "\n")
    except Exception as e:
        print(f"Logging failed: {e}")

log_debug("Applied sys.path fix", {"cwd": os.getcwd(), "sys_path": sys.path})
# #endregion

from src.data.scaffolds import load_scaffold
OUT = Path("results")
sc = load_scaffold("1AKL","A", OUT/"scaffolds")  # change PDB/chain
print(sc.pdb_path)
print("length:", len(sc.sequence))
print(sc.sequence[:120] + "...")
# Out:
# Error:
